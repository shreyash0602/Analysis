# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Shreyash Priyadarshi**<br>Senior Executive, Entrepreneurship Cell

# %% [markdown]
# *I am interested in data science because I like to build models and discover the underlying facts behind the data.*

# %% [markdown]
# ### I will be adding two numbers in the next cell.

# %%
1+1
# Out:
# 2

# %% [markdown]
# Horizontal Rule<hr>
# <ol><li>Item 1</li>
#     <li>Item 2</li>
#     <li>Item 3</li>
# </ol>
#
# ~~Strikethrough~~
#
# <ul><li>First</li>
#     <li>Second</li>
#     <li>Third</li>
# </ul>
